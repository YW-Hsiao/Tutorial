# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]           # Step 1
y = [5, 10, 20, 35, 45]       # Step 1
fig = plt.figure()            # Step 2
ax = fig.add_subplot(111)     # Step 3
plt.plot(x, y, color='blue', linewidth=2, marker='o') # Step 3&4
plt.xlim(1, 5.5)                   
plt.savefig('workflow.png')   # Step 5
plt.show()                    # Step 6

# %%
fig1, ax1 = plt.plot(figsize=(10,10))  # plot size
fig2, ax2 = plt.plot(figsize=(10,10))  # plot size
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-7e16f16254ca> in <module>
# ----> 1 fig1, ax1 = plt.plot(figsize=(10,10))  # plot size
#       2 fig2, ax2 = plt.plot(figsize=(10,10))  # plot size
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
plt.plot()
plt.legned

# %%
fig1 = plt.figure()
fig2 = plt.figure()
ax2 = fig2.add_subplot(2, 1, 1)
ax1 = fig1.add_subplot(1, 1, 1)
ax3 = fig2.add_subplot(2, 1, 2)
ax2.xlabel('2')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-0a22cff594a3> in <module>
#       4 ax1 = fig1.add_subplot(1, 1, 1)
#       5 ax3 = fig2.add_subplot(2, 1, 2)
# ----> 6 ax2.xlabel('2')
#
# AttributeError: 'AxesSubplot' object has no attribute 'xlabel'

# %%
a = 5
b = 4

# %%
a
b
# Out:
# 4

# %%
plt.figure()
plt.hist([1,2,3])
plt.legend()




plt.figure()
plt.plot([1,2,3])
plt.legend()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
