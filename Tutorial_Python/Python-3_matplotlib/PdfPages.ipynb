# %% [markdown]
# # PdfPages
# https://matplotlib.org/devdocs/api/_as_gen/matplotlib.pyplot.savefig.html

# %% [markdown]
# ## 1. 如何在 Matplotlib 中將圖另存為 PDF 檔案
# https://www.delftstack.com/zh-tw/howto/matplotlib/how-to-save-plots-as-pdf-file-in-matplotlib/

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(0,5,50)
y=np.cos(2 * np.pi * x)

plt.scatter(x, y)
plt.plot(x, y)
plt.title("Plot of cosx")
plt.xlabel("x")
plt.ylabel("cosx")
plt.show()
plt.savefig("Save Plot as PDF file using savefig 1.pdf")

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(0,5,50)
y=np.cos(2 * np.pi * x)

plt.scatter(x, y)
plt.plot(x, y)
plt.title("Plot of cosx")
plt.xlabel("x")
plt.ylabel("cosx")
plt.savefig("Save Plot as PDF file using savefig 2.pdf")
plt.show()

# %% [markdown]
# #### Conclusion: savefig() must be in front of show().

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

x=np.linspace(-3,3,100)
y1=np.sin(x)
y2=np.cos(x)
y3=1/(1+np.exp(-x))
y4=np.exp(x)

def retFig(x, y):
    fig = plt.figure()
    a= plt.plot(x, y)
    return fig

fig1 = retFig(x, y1)
fig2 = retFig(x, y2)
fig3 = retFig(x, y3)
fig4 = retFig(x, y4)

pp = PdfPages('Save multiple plots as PDF.pdf')
pp.savefig(fig1)
pp.savefig(fig2)
pp.savefig(fig3)
pp.savefig(fig4)
pp.close()

# %% [markdown]
# ## 2. Multipage PDF
# https://matplotlib.org/devdocs/api/backend_pdf_api.html#matplotlib.backends.backend_pdf.PdfPages
# https://matplotlib.org/stable/gallery/misc/multipage_pdf.html

# %%
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
# Initialize:
with PdfPages('foo.pdf') as pdf:
    # As many times as you like, create a figure fig and save it:
    fig = plt.figure()
    pdf.savefig(fig)
    # When no figure is specified the current figure is saved
    pdf.savefig()

# %%
# I modify the above PdfPages code.

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
# Initialize:

x = np.linspace(-np.pi, np.pi, 101)
y1 = x
y2 = x**2
y3 = np.sin(x)
y4 = np.cos(x)

with PdfPages('foo test.pdf') as pdf:
    # As many times as you like, create a figure fig and save it:
    fig1 = plt.figure()
    plt.plot(x, y1)
    fig2 = plt.figure()
    plt.plot(x, y2)
    fig3 = plt.figure()
    plt.plot(x, y3)
    fig4 = plt.figure()
    plt.plot(x, y4)
    
    pdf.savefig(fig1)
    pdf.savefig(fig2)
    pdf.savefig(fig3)
    pdf.savefig(fig4)
    
    # When no figure is specified the current figure is saved
    pdf.savefig()

# %%
x
# Out:
# array([-3.14159265e+00, -3.07876080e+00, -3.01592895e+00, -2.95309709e+00,
#        -2.89026524e+00, -2.82743339e+00, -2.76460154e+00, -2.70176968e+00,
#        -2.63893783e+00, -2.57610598e+00, -2.51327412e+00, -2.45044227e+00,
#        -2.38761042e+00, -2.32477856e+00, -2.26194671e+00, -2.19911486e+00,
#        -2.13628300e+00, -2.07345115e+00, -2.01061930e+00, -1.94778745e+00,
#        -1.88495559e+00, -1.82212374e+00, -1.75929189e+00, -1.69646003e+00,
#        -1.63362818e+00, -1.57079633e+00, -1.50796447e+00, -1.44513262e+00,
#        -1.38230077e+00, -1.31946891e+00, -1.25663706e+00, -1.19380521e+00,
#        -1.13097336e+00, -1.06814150e+00, -1.00530965e+00, -9.42477796e-01,
#        -8.79645943e-01, -8.16814090e-01, -7.53982237e-01, -6.91150384e-01,
#        -6.28318531e-01, -5.65486678e-01, -5.02654825e-01, -4.39822972e-01,
#        -3.76991118e-01, -3.14159265e-01, -2.51327412e-01, -1.88495559e-01,
# ...

# %%
y4
# Out:
# array([-1.00000000e+00, -9.98026728e-01, -9.92114701e-01, -9.82287251e-01,
#        -9.68583161e-01, -9.51056516e-01, -9.29776486e-01, -9.04827052e-01,
#        -8.76306680e-01, -8.44327926e-01, -8.09016994e-01, -7.70513243e-01,
#        -7.28968627e-01, -6.84547106e-01, -6.37423990e-01, -5.87785252e-01,
#        -5.35826795e-01, -4.81753674e-01, -4.25779292e-01, -3.68124553e-01,
#        -3.09016994e-01, -2.48689887e-01, -1.87381315e-01, -1.25333234e-01,
#        -6.27905195e-02,  2.83276945e-16,  6.27905195e-02,  1.25333234e-01,
#         1.87381315e-01,  2.48689887e-01,  3.09016994e-01,  3.68124553e-01,
#         4.25779292e-01,  4.81753674e-01,  5.35826795e-01,  5.87785252e-01,
#         6.37423990e-01,  6.84547106e-01,  7.28968627e-01,  7.70513243e-01,
#         8.09016994e-01,  8.44327926e-01,  8.76306680e-01,  9.04827052e-01,
#         9.29776486e-01,  9.51056516e-01,  9.68583161e-01,  9.82287251e-01,
# ...

# %%
fig1

# %%
fig2

# %%
fig3

# %%
fig4

# %%
import datetime
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pyplot as plt

# Create the PdfPages object to which we will save the pages:
# The with statement makes sure that the PdfPages object is closed properly at
# the end of the block, even if an Exception occurs.
with PdfPages('multipage_pdf.pdf') as pdf:
    plt.figure(figsize=(3, 3))
    plt.plot(range(7), [3, 1, 4, 1, 5, 9, 2], 'r-o')
    plt.title('Page One')
    pdf.savefig()  # saves the current figure into a pdf page
    plt.close()

    # if LaTeX is not installed or error caught, change to `False`
    plt.rcParams['text.usetex'] = True
    plt.figure(figsize=(8, 6))
    x = np.arange(0, 5, 0.1)
    plt.plot(x, np.sin(x), 'b-')
    plt.title('Page Two')
    pdf.attach_note("plot of sin(x)")  # attach metadata (as pdf note) to page
    pdf.savefig()
    plt.close()

    plt.rcParams['text.usetex'] = False
    fig = plt.figure(figsize=(4, 5))
    plt.plot(x, x ** 2, 'ko')
    plt.title('Page Three')
    pdf.savefig(fig)  # or you can pass a Figure object to pdf.savefig
    plt.close()

    # We can also set the file's metadata via the PdfPages object:
    d = pdf.infodict()
    d['Title'] = 'Multipage PDF Example'
    d['Author'] = 'Jouni K. Sepp\xe4nen'
    d['Subject'] = 'How to create a multipage pdf file and set its metadata'
    d['Keywords'] = 'PdfPages multipage keywords author title subject'
    d['CreationDate'] = datetime.datetime(2009, 11, 13)
    d['ModDate'] = datetime.datetime.today()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     274         try:
# --> 275             report = subprocess.check_output(command,
#     276                                              cwd=self.texcache,
#
# /usr/lib/python3.8/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     410
# --> 411     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     412                **kwargs).stdout
#
# /usr/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     488
# --> 489     with Popen(*popenargs, **kwargs) as process:
#     490         try:
#
# ...

# %% [markdown]
# ## 3. Saving
